# %%
import os 
import sys
module_path = os.path.abspath(os.path.join('..'))
sys.path.append(module_path)

# %%
from route_dynamics.route_riders import route_riders as ride
# Out:
# /Users/ryanjcarlin/miniconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3185: DtypeWarning: Columns (46) have mixed types. Specify dtype option on import or set low_memory=False.
#   if (yield from self.run_code(code, result)):

# %%
pm_i_45df, pm_i_45ride, pm_i_45mass = ride.route_ridership('PM', 'I', 45)

# %%
am_i_45df, am_i_45ride, am_i_45mass = ride.route_ridership('AM', 'I', 45)

# %%
am_o_45df, am_o_45ride, am_o_45mass = ride.route_ridership('AM', 'O', 45)

# %%
riders_45.head()
# Out:
#    STOP_SEQ        Mean
# 0   35530.0  101.647059
# 1   35540.0  112.000000
# 2   35550.0  121.333333
# 3   19210.0  132.888889
# 4   35551.0  153.333333

# %%
import matplotlib as plt

# %%
pm_i_45ride.plot(y='Mean')

# %%
am_i_45ride.plot(y='Mean')

# %%
am_o_45ride.plot(y='Mean')
