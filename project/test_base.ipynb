# %%
import base

# %%
shapefile = '../data/six_routes.shp'
rasterfile = '../data/sea_dtm_north.tif'
route_num = 45

# %%
def test_read_shape():
    """Test if shapefile is for route number 45"""    
    assert base.read_shape(shapefile,45)['ROUTE_NUM'].values[0] == 40, 'ROUTE_NUM is wrong!'
    return

# %%
def test_extract_point_df():
    """Test"""
    df45 = base.read_shape(shapefile, route_num)
    shape = base.extract_point_df(df45).shape
    assert shape == (208,1), " Shape of df(route 45) coordinates should be (208,1)"
    return

# %%
test_extract_point_df()
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-72-09827de53808> in <module>
# ----> 1 test_extract_point_df()
#
# <ipython-input-71-22da7c37c923> in test_extract_point_df()
#       3     df45 = base.read_shape(shapefile, route_num)
#       4     shape = base.extract_point_df(df45).shape
# ----> 5     assert shape == (207,1), " Shape of df(route 45) coordinates should be (208,1)"
#       6     return
#
# AssertionError:  Shape of df(route 45) coordinates should be (208,1)

# %%
# map_display, route_plot, route_diff_metrics = route_analysis(45, shapefile, rasterfile)
map_display, route_plot = single_route.route_analysis(45, shapefile, rasterfile)
map_display
# Out:
# <iframe src="data:text/html;charset=utf-8;base64,..." width="100%" height="400"style="border:none !important;" "allowfullscreen" "webkitallowfullscreen" "mozallowfullscreen"></iframe>
